# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import numpy as np
import random

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#device = 'cpu'

# Hyper-parameters
num_epochs = 50
learning_rate = 0.0001

Half_width =256
layer_width=512

torch.manual_seed(0)
random.seed(0)

# Image preprocessing modules
# Normalize training set together with augmentation
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.507, 0.487, 0.441], std=[0.267, 0.256, 0.276])
])

# Normalize test set same as training set without augmentation
transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.507, 0.487, 0.441], std=[0.267, 0.256, 0.276])
])

# CIFAR-100 dataset

trainset = torchvision.datasets.CIFAR100(root='./data',
                                         train=True,
                                         download=True,
                                         transform=transform_train)
train_loader = torch.utils.data.DataLoader(
    trainset, batch_size=200, shuffle=True, num_workers=0)

testset = torchvision.datasets.CIFAR100(root='./data',
                                        train=False,
                                        download=True,
                                        transform=transform_test)
test_loader = torch.utils.data.DataLoader(
    testset, batch_size=200, shuffle=False, num_workers=0)



def conv3x3(in_channels, out_channels, stride=1):
    """3x3 kernel size with padding convolutional layer in ResNet BasicBlock."""
    return nn.Conv2d(
        in_channels=in_channels,
        out_channels=out_channels,
        kernel_size=3,
        stride=stride,
        padding=1,
        bias=False)


cfg = {
    'A' : [64,     'M', 128,      'M', 256, 256,           'M', 512, 512,           'M', 512, 512,           'M'],
    'B' : [64, 64, 'M', 128, 128, 'M', 256, 256,           'M', 512, 512,           'M', 512, 512,           'M'],
    'D' : [64, 64, 'M', 128, 128, 'M', 256, 256, 256,      'M', 512, 512, 512,      'M', 512, 512, 512,      'M'],
    'E' : [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 256, 'M', 512, 512, 512, 512, 'M', 512, 512, 512, 512, 'M']
}
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
#   0%|          | 0/169001437 [00:00<?, ?it/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified

# %%
class VGG(nn.Module):

    def __init__(self, features, num_class=100):
        super().__init__()
        self.features = features

        self.classifier = nn.Sequential(
            nn.Linear(512, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(4096, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(4096, num_class)
        )

    def forward(self, x):
        output = self.features(x)
        output = output.view(output.size()[0], -1)
        output = self.classifier(output)
    
        return output

# %%
class SpinalVGG(nn.Module):

    def __init__(self, features, num_class=100):
        super().__init__()
        self.features = features
        
        self.fc_spinal_layer1 = nn.Sequential(
            nn.Dropout(), nn.Linear(Half_width, layer_width),
            nn.ReLU(inplace=True),
            )
        self.fc_spinal_layer2 = nn.Sequential(
            nn.Dropout(), nn.Linear(Half_width + layer_width, layer_width),
            nn.ReLU(inplace=True),
            )
        self.fc_spinal_layer3 = nn.Sequential(
            nn.Dropout(), nn.Linear(Half_width + layer_width, layer_width),
            nn.ReLU(inplace=True),
            )
        self.fc_spinal_layer4 = nn.Sequential(
            nn.Dropout(), nn.Linear(Half_width + layer_width, layer_width),
            nn.ReLU(inplace=True),
            )
        self.fc_out = nn.Sequential(
            nn.Dropout(), nn.Linear(layer_width*4, num_class)            
            )


    def forward(self, x):
        output = self.features(x)
        output = output.view(output.size()[0], -1)
        x = output
        x1 = self.fc_spinal_layer1(x[:, 0:Half_width])
        x2 = self.fc_spinal_layer2(torch.cat([ x[:,Half_width:2*Half_width], x1], dim=1))
        x3 = self.fc_spinal_layer3(torch.cat([ x[:,0:Half_width], x2], dim=1))
        x4 = self.fc_spinal_layer4(torch.cat([ x[:,Half_width:2*Half_width], x3], dim=1))
        
        x = torch.cat([x1, x2], dim=1)
        x = torch.cat([x, x3], dim=1)
        x = torch.cat([x, x4], dim=1)
        
        x = self.fc_out(x)
    
        return x
    

def make_layers(cfg, batch_norm=False):
    layers = []

    input_channel = 3
    for l in cfg:
        if l == 'M':
            layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
            continue

        layers += [nn.Conv2d(input_channel, l, kernel_size=3, padding=1)]

        if batch_norm:
            layers += [nn.BatchNorm2d(l)]
        
        layers += [nn.ReLU(inplace=True)]
        input_channel = l
    
    return nn.Sequential(*layers)

def vgg11_bn():
    return VGG(make_layers(cfg['A'], batch_norm=True))

def vgg13_bn():
    return VGG(make_layers(cfg['B'], batch_norm=True))

def vgg16_bn():
    return VGG(make_layers(cfg['D'], batch_norm=True))

def vgg19_bn():
    return VGG(make_layers(cfg['E'], batch_norm=True))

def Spinalvgg11_bn():
    return SpinalVGG(make_layers(cfg['A'], batch_norm=True))

def Spinalvgg13_bn():
    return SpinalVGG(make_layers(cfg['B'], batch_norm=True))

def Spinalvgg16_bn():
    return SpinalVGG(make_layers(cfg['D'], batch_norm=True))

def Spinalvgg19_bn():
    return SpinalVGG(make_layers(cfg['E'], batch_norm=True))



# For updating learning rate
def update_lr(optimizer, lr):    
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# Train the model
total_step = len(train_loader)
curr_lr1 = learning_rate

curr_lr2 = learning_rate



model1 = vgg19_bn().to(device)

model2 = Spinalvgg19_bn().to(device)



# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer1 = torch.optim.Adam(model1.parameters(), lr=learning_rate)
optimizer2 = torch.optim.Adam(model2.parameters(), lr=learning_rate) 
  
# Train the model
total_step = len(train_loader)

best_accuracy1 = 0
best_accuracy2 =0
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):
        images = images.to(device)
        labels = labels.to(device)

        # Forward pass
        outputs = model1(images)
        loss1 = criterion(outputs, labels)

        # Backward and optimize
        optimizer1.zero_grad()
        loss1.backward()
        optimizer1.step()
        
        outputs = model2(images)
        loss2 = criterion(outputs, labels)

        # Backward and optimize
        optimizer2.zero_grad()
        loss2.backward()
        optimizer2.step()

        if i == 249:
            print ("Ordinary Epoch [{}/{}], Step [{}/{}] Loss: {:.4f}"
                   .format(epoch+1, num_epochs, i+1, total_step, loss1.item()))
            print ("Spinal Epoch [{}/{}], Step [{}/{}] Loss: {:.4f}"
                   .format(epoch+1, num_epochs, i+1, total_step, loss2.item()))


        
    # Test the model
    model1.eval()
    model2.eval()
    with torch.no_grad():
        correct1 = 0
        total1 = 0
        correct2 = 0
        total2 = 0
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)
            
            
            outputs = model1(images)
            _, predicted = torch.max(outputs.data, 1)
            total1 += labels.size(0)
            correct1 += (predicted == labels).sum().item()
            
            outputs = model2(images)
            _, predicted = torch.max(outputs.data, 1)
            total2 += labels.size(0)
            correct2 += (predicted == labels).sum().item()
    
        
        if best_accuracy1> correct1 / total1:
            curr_lr1 = learning_rate*np.asscalar(pow(np.random.rand(1),3))
            update_lr(optimizer1, curr_lr1)
            print('Test Accuracy of NN: {} % Best: {} %'.format(100 * correct1 / total1, 100*best_accuracy1))
        else:
            best_accuracy1 = correct1 / total1
            net_opt1 = model1
            print('Test Accuracy of NN: {} % (improvement)'.format(100 * correct1 / total1))
            
        if best_accuracy2> correct2 / total2:
            curr_lr2 = learning_rate*np.asscalar(pow(np.random.rand(1),3))
            update_lr(optimizer2, curr_lr2)
            print('Test Accuracy of SpinalNet: {} % Best: {} %'.format(100 * correct2 / total2, 100*best_accuracy2))
        else:
            best_accuracy2 = correct2 / total2
            net_opt2 = model2
            print('Test Accuracy of SpinalNet: {} % (improvement)'.format(100 * correct2 / total2))

        
            
        model1.train()
        model2.train()
# Out:
# Ordinary Epoch [1/50], Step [250/250] Loss: 4.0120
# Spinal Epoch [1/50], Step [250/250] Loss: 4.2459
# Test Accuracy of NN: 9.25 % (improvement)
# Test Accuracy of SpinalNet: 6.12 % (improvement)
# Ordinary Epoch [2/50], Step [250/250] Loss: 3.3794
# Spinal Epoch [2/50], Step [250/250] Loss: 3.6892
# Test Accuracy of NN: 15.75 % (improvement)
# Test Accuracy of SpinalNet: 10.69 % (improvement)
# Ordinary Epoch [3/50], Step [250/250] Loss: 2.9432
# Spinal Epoch [3/50], Step [250/250] Loss: 3.2395
# Test Accuracy of NN: 20.72 % (improvement)
# Test Accuracy of SpinalNet: 17.66 % (improvement)
# Ordinary Epoch [4/50], Step [250/250] Loss: 2.8275
# Spinal Epoch [4/50], Step [250/250] Loss: 3.0848
# Test Accuracy of NN: 27.56 % (improvement)
# Test Accuracy of SpinalNet: 21.17 % (improvement)
# Ordinary Epoch [5/50], Step [250/250] Loss: 2.6101
# Spinal Epoch [5/50], Step [250/250] Loss: 2.6924
# Test Accuracy of NN: 29.57 % (improvement)
# Test Accuracy of SpinalNet: 24.45 % (improvement)
# Ordinary Epoch [6/50], Step [250/250] Loss: 2.4993
# Spinal Epoch [6/50], Step [250/250] Loss: 2.6460
# Test Accuracy of NN: 32.83 % (improvement)
# Test Accuracy of SpinalNet: 31.49 % (improvement)
# Ordinary Epoch [7/50], Step [250/250] Loss: 2.2622
# Spinal Epoch [7/50], Step [250/250] Loss: 2.4177
# Test Accuracy of NN: 36.55 % (improvement)
# Test Accuracy of SpinalNet: 35.31 % (improvement)
# Ordinary Epoch [8/50], Step [250/250] Loss: 2.2233
# Spinal Epoch [8/50], Step [250/250] Loss: 2.4072
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:175: DeprecationWarning: np.asscalar(a) is deprecated since NumPy v1.16, use a.item() instead
# Test Accuracy of NN: 36.1 % Best: 36.55 %
# Test Accuracy of SpinalNet: 37.05 % (improvement)
# Ordinary Epoch [9/50], Step [250/250] Loss: 2.0973
# Spinal Epoch [9/50], Step [250/250] Loss: 2.2458
# Test Accuracy of NN: 43.45 % (improvement)
# Test Accuracy of SpinalNet: 40.34 % (improvement)
# Ordinary Epoch [10/50], Step [250/250] Loss: 1.7858
# Spinal Epoch [10/50], Step [250/250] Loss: 1.9992
# Test Accuracy of NN: 44.07 % (improvement)
# Test Accuracy of SpinalNet: 39.54 % Best: 40.339999999999996 %
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:184: DeprecationWarning: np.asscalar(a) is deprecated since NumPy v1.16, use a.item() instead
# Ordinary Epoch [11/50], Step [250/250] Loss: 1.9461
# Spinal Epoch [11/50], Step [250/250] Loss: 1.9538
# Test Accuracy of NN: 44.94 % (improvement)
# Test Accuracy of SpinalNet: 48.26 % (improvement)
# Ordinary Epoch [12/50], Step [250/250] Loss: 1.8600
# Spinal Epoch [12/50], Step [250/250] Loss: 1.7785
# Test Accuracy of NN: 45.55 % (improvement)
# Test Accuracy of SpinalNet: 49.46 % (improvement)
# Ordinary Epoch [13/50], Step [250/250] Loss: 1.5786
# Spinal Epoch [13/50], Step [250/250] Loss: 1.5755
# Test Accuracy of NN: 46.75 % (improvement)
# Test Accuracy of SpinalNet: 49.43 % Best: 49.46 %
# Ordinary Epoch [14/50], Step [250/250] Loss: 1.8317
# Spinal Epoch [14/50], Step [250/250] Loss: 1.7956
# Test Accuracy of NN: 48.28 % (improvement)
# Test Accuracy of SpinalNet: 49.79 % (improvement)
# Ordinary Epoch [15/50], Step [250/250] Loss: 1.4869
# Spinal Epoch [15/50], Step [250/250] Loss: 1.5844
# Test Accuracy of NN: 48.1 % Best: 48.28 %
# Test Accuracy of SpinalNet: 50.0 % (improvement)
# Ordinary Epoch [16/50], Step [250/250] Loss: 1.4968
# Spinal Epoch [16/50], Step [250/250] Loss: 1.6814
# Test Accuracy of NN: 51.9 % (improvement)
# Test Accuracy of SpinalNet: 49.87 % Best: 50.0 %
# Ordinary Epoch [17/50], Step [250/250] Loss: 1.4709
# Spinal Epoch [17/50], Step [250/250] Loss: 2.1214
# Test Accuracy of NN: 52.23 % (improvement)
# Test Accuracy of SpinalNet: 44.63 % Best: 50.0 %
# Ordinary Epoch [18/50], Step [250/250] Loss: 1.3058
# Spinal Epoch [18/50], Step [250/250] Loss: 1.4677
# Test Accuracy of NN: 52.59 % (improvement)
# Test Accuracy of SpinalNet: 51.19 % (improvement)
# Ordinary Epoch [19/50], Step [250/250] Loss: 1.3923
# Spinal Epoch [19/50], Step [250/250] Loss: 1.5727
# Test Accuracy of NN: 52.57 % Best: 52.59 %
# Test Accuracy of SpinalNet: 51.56 % (improvement)
# Ordinary Epoch [20/50], Step [250/250] Loss: 1.2891
# Spinal Epoch [20/50], Step [250/250] Loss: 1.5227
# Test Accuracy of NN: 53.09 % (improvement)
# Test Accuracy of SpinalNet: 51.15 % Best: 51.559999999999995 %
# Ordinary Epoch [21/50], Step [250/250] Loss: 1.4527
# Spinal Epoch [21/50], Step [250/250] Loss: 1.6901
# Test Accuracy of NN: 53.22 % (improvement)
# Test Accuracy of SpinalNet: 52.13 % (improvement)
# Ordinary Epoch [22/50], Step [250/250] Loss: 1.4552
# Spinal Epoch [22/50], Step [250/250] Loss: 1.4366
# Test Accuracy of NN: 53.15 % Best: 53.22 %
# Test Accuracy of SpinalNet: 52.33 % (improvement)
# Ordinary Epoch [23/50], Step [250/250] Loss: 1.2164
# Spinal Epoch [23/50], Step [250/250] Loss: 1.4538
# Test Accuracy of NN: 53.16 % Best: 53.22 %
# Test Accuracy of SpinalNet: 52.56 % (improvement)
# Ordinary Epoch [24/50], Step [250/250] Loss: 1.2399
# Spinal Epoch [24/50], Step [250/250] Loss: 1.4322
# Test Accuracy of NN: 53.54 % (improvement)
# Test Accuracy of SpinalNet: 52.76 % (improvement)
# Ordinary Epoch [25/50], Step [250/250] Loss: 1.3386
# Spinal Epoch [25/50], Step [250/250] Loss: 1.4959
# Test Accuracy of NN: 53.44 % Best: 53.54 %
# Test Accuracy of SpinalNet: 52.83 % (improvement)
# Ordinary Epoch [26/50], Step [250/250] Loss: 1.2993
# Spinal Epoch [26/50], Step [250/250] Loss: 1.3169
# Test Accuracy of NN: 52.58 % Best: 53.54 %
# Test Accuracy of SpinalNet: 52.92 % (improvement)
# Ordinary Epoch [27/50], Step [250/250] Loss: 1.6001
# Spinal Epoch [27/50], Step [250/250] Loss: 1.4914
# Test Accuracy of NN: 49.46 % Best: 53.54 %
# Test Accuracy of SpinalNet: 53.11 % (improvement)
# Ordinary Epoch [28/50], Step [250/250] Loss: 1.5423
# Spinal Epoch [28/50], Step [250/250] Loss: 1.4017
# Test Accuracy of NN: 50.9 % Best: 53.54 %
# Test Accuracy of SpinalNet: 53.16 % (improvement)
# Ordinary Epoch [29/50], Step [250/250] Loss: 1.1996
# Spinal Epoch [29/50], Step [250/250] Loss: 1.4832
# Test Accuracy of NN: 54.01 % (improvement)
# Test Accuracy of SpinalNet: 53.15 % Best: 53.16 %
# Ordinary Epoch [30/50], Step [250/250] Loss: 1.2131
# Spinal Epoch [30/50], Step [250/250] Loss: 1.3540
# Test Accuracy of NN: 54.51 % (improvement)
# Test Accuracy of SpinalNet: 53.36 % (improvement)
# Ordinary Epoch [31/50], Step [250/250] Loss: 1.2436
# Spinal Epoch [31/50], Step [250/250] Loss: 1.4499
# Test Accuracy of NN: 54.67 % (improvement)
# Test Accuracy of SpinalNet: 53.15 % Best: 53.36 %
# Ordinary Epoch [32/50], Step [250/250] Loss: 1.3144
# Spinal Epoch [32/50], Step [250/250] Loss: 1.5065
# Test Accuracy of NN: 54.79 % (improvement)
# Test Accuracy of SpinalNet: 53.36 % (improvement)
# Ordinary Epoch [33/50], Step [250/250] Loss: 1.1169
# Spinal Epoch [33/50], Step [250/250] Loss: 1.4447
# Test Accuracy of NN: 54.99 % (improvement)
# Test Accuracy of SpinalNet: 53.7 % (improvement)
# Ordinary Epoch [34/50], Step [250/250] Loss: 1.2162
# Spinal Epoch [34/50], Step [250/250] Loss: 1.5539
# Test Accuracy of NN: 54.98 % Best: 54.99000000000001 %
# Test Accuracy of SpinalNet: 53.32 % Best: 53.7 %
# Ordinary Epoch [35/50], Step [250/250] Loss: 1.0373
# Spinal Epoch [35/50], Step [250/250] Loss: 1.2244
# Test Accuracy of NN: 55.26 % (improvement)
# Test Accuracy of SpinalNet: 53.5 % Best: 53.7 %
# Ordinary Epoch [36/50], Step [250/250] Loss: 1.1488
# Spinal Epoch [36/50], Step [250/250] Loss: 1.3854
# Test Accuracy of NN: 55.35 % (improvement)
# Test Accuracy of SpinalNet: 53.38 % Best: 53.7 %
# Ordinary Epoch [37/50], Step [250/250] Loss: 1.0285
# Spinal Epoch [37/50], Step [250/250] Loss: 1.4249
# Test Accuracy of NN: 55.25 % Best: 55.35 %
# Test Accuracy of SpinalNet: 53.5 % Best: 53.7 %
# Ordinary Epoch [38/50], Step [250/250] Loss: 1.1994
# Spinal Epoch [38/50], Step [250/250] Loss: 1.6534
# Test Accuracy of NN: 54.62 % Best: 55.35 %
# Test Accuracy of SpinalNet: 51.07 % Best: 53.7 %
# Ordinary Epoch [39/50], Step [250/250] Loss: 1.0841
# Spinal Epoch [39/50], Step [250/250] Loss: 1.4712
# Test Accuracy of NN: 54.67 % Best: 55.35 %
# Test Accuracy of SpinalNet: 53.15 % Best: 53.7 %
# Ordinary Epoch [40/50], Step [250/250] Loss: 0.9528
# Spinal Epoch [40/50], Step [250/250] Loss: 1.2299
# Test Accuracy of NN: 54.82 % Best: 55.35 %
# Test Accuracy of SpinalNet: 55.0 % (improvement)
# Ordinary Epoch [41/50], Step [250/250] Loss: 1.1935
# Spinal Epoch [41/50], Step [250/250] Loss: 1.4003
# Test Accuracy of NN: 55.1 % Best: 55.35 %
# Test Accuracy of SpinalNet: 54.76 % Best: 55.00000000000001 %
# Ordinary Epoch [42/50], Step [250/250] Loss: 1.3307
# Spinal Epoch [42/50], Step [250/250] Loss: 1.5409
# Test Accuracy of NN: 55.26 % Best: 55.35 %
# Test Accuracy of SpinalNet: 54.97 % Best: 55.00000000000001 %
# Ordinary Epoch [43/50], Step [250/250] Loss: 1.3475
# Spinal Epoch [43/50], Step [250/250] Loss: 1.4913
# Test Accuracy of NN: 51.27 % Best: 55.35 %
# Test Accuracy of SpinalNet: 51.99 % Best: 55.00000000000001 %
# Ordinary Epoch [44/50], Step [250/250] Loss: 1.2673
# Spinal Epoch [44/50], Step [250/250] Loss: 1.3172
# Test Accuracy of NN: 51.03 % Best: 55.35 %
# Test Accuracy of SpinalNet: 53.81 % Best: 55.00000000000001 %
# Ordinary Epoch [45/50], Step [250/250] Loss: 1.1552
# Spinal Epoch [45/50], Step [250/250] Loss: 1.2171
# Test Accuracy of NN: 55.8 % (improvement)
# Test Accuracy of SpinalNet: 56.39 % (improvement)
# Ordinary Epoch [46/50], Step [250/250] Loss: 1.0348
# Spinal Epoch [46/50], Step [250/250] Loss: 1.1126
# Test Accuracy of NN: 56.04 % (improvement)
# Test Accuracy of SpinalNet: 56.51 % (improvement)
# Ordinary Epoch [47/50], Step [250/250] Loss: 1.1298
# Spinal Epoch [47/50], Step [250/250] Loss: 1.3222
# Test Accuracy of NN: 55.86 % Best: 56.04 %
# Test Accuracy of SpinalNet: 56.57 % (improvement)
# Ordinary Epoch [48/50], Step [250/250] Loss: 1.0291
# Spinal Epoch [48/50], Step [250/250] Loss: 1.0522
# Test Accuracy of NN: 55.36 % Best: 56.04 %
# Test Accuracy of SpinalNet: 56.76 % (improvement)
# Ordinary Epoch [49/50], Step [250/250] Loss: 1.0729
# Spinal Epoch [49/50], Step [250/250] Loss: 1.1773
# Test Accuracy of NN: 55.21 % Best: 56.04 %
# Test Accuracy of SpinalNet: 56.68 % Best: 56.76 %
# Ordinary Epoch [50/50], Step [250/250] Loss: 1.3224
# Spinal Epoch [50/50], Step [250/250] Loss: 1.2837
# Test Accuracy of NN: 53.99 % Best: 56.04 %
# Test Accuracy of SpinalNet: 56.97 % (improvement)
